# %% [markdown]
# <a href="https://colab.research.google.com/github/Kadidjah/Engenharia_de_Prompt_e_Aplicacao_AI/blob/main/ProgramacaoAssistidaPorAI_aula07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 07 _ Miniprojeto
#
# Nome: Kadidja Valéria
# Disciplina: Engenharia de Prompt e Aplicação em IA

# %%
print("Olá, turma de quarta-feira!")
# Out:
# Olá, turma de quarta-feira!

# %%
numeros = [] # Exemplo de lista
soma=0
i=0
while i < len(numeros):
  soma=soma+numeros[i]
  i=i+1
  print(soma)
